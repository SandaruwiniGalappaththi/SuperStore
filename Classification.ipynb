# %% [markdown]
# <a href="https://colab.research.google.com/github/SandaruwiniGalappaththi/SuperStore/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install pyspark
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.5)

# %%
# Import SparkSession
from pyspark.sql import SparkSession
# Create a Spark Session
spark = SparkSession.builder.master("local[*]").getOrCreate()
# Check Spark Session Information
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://26c2f0f50d09:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### **Importing packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Importing superstore dataset**

# %%
url = "https://raw.githubusercontent.com/SupunGurusinghe/ML-with-superstore-dataset/main/superstore_data.csv"
superstore_df = pd.read_csv(url ,encoding='windows-1252')
superstore_df
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 0         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1         2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2         3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4         5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...     ...             ...         ...         ...             ...
# 9989   9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990   9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991   9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992   9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993   9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID      CustomerName    Segment        Country             City  \
# 0      CG-12520       Claire Gute   Consumer  United States        Henderson
# 1      CG-12520       Claire Gute   Consumer  United States        Henderson
# 2      DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...         ...               ...        ...            ...              ...
# 9989   TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993   CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... PostalCode  Region        ProductID         Category  SubCategory  \
# 0     ...      42420   South  FUR-BO-10001798              NaN    Bookcases
# 1     ...      42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...      90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...      33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...      33311   South  OFF-ST-10000760  Office Suplease      Storage
# ...   ...        ...     ...              ...              ...          ...
# 9989  ...      33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...      92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...      92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...      92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...      92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             ProductName     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %% [markdown]
# ### **Creating schema for data set**

# %%
from pyspark.sql.types import *

sales_schema = StructType([
    StructField("RowID", IntegerType(), False),
    StructField("OrderID", StringType(), False),
    StructField("OrderDate", StringType(), False, metadata={"desc": "Date of order placed"}),
    StructField("ShipDate", StringType(), False, metadata={"desc": "Date of order shipped"}),
    StructField("ShipMode", StringType(), True, metadata={"desc": "Mode of shipment"}),
    StructField("CustomerID", StringType(), False),
    StructField("CustomerName", StringType(), True),
    StructField("Segment", StringType(), True, metadata={"desc": "Type of the customer"}),
    StructField("Country", StringType(), True),
    StructField("City", StringType(), False),
    StructField("State", StringType(), True),
    StructField("PostalCode", StringType(), True),
    StructField("Region", StringType(), True),
    StructField("ProductID", StringType(), False),
    StructField("Category", StringType(), True),
    StructField("SubCategory", StringType(), True),
    StructField("ProductName", StringType(), True),
    StructField("Sales", FloatType(), False),
    StructField("Quantity", IntegerType(), False),
    StructField("Discount", FloatType(), False),
    StructField("Profit", FloatType(), False),
])

# %% [markdown]
# ### **Converting to PySpark dataframe**

# %%
superstore_df = spark.createDataFrame(superstore_df, sales_schema)
superstore_df.show()
# Out:
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# |RowID|       OrderID| OrderDate|  ShipDate|      ShipMode|CustomerID|      CustomerName|    Segment|      Country|           City|         State|PostalCode| Region|      ProductID|       Category|SubCategory|         ProductName|   Sales|Quantity|Discount|  Profit|
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# |   16|US-2015-118983|11/22/2015|11/26/2015|Standard Class|  HP-14815|     Harold Pawlan|Home Office|United States|     Fort Worth|         Texas|     76106|Central|OFF-BI-10000756|Office Supplies|    Binders|Storex DuraTech R...|   2.544|       3|     0.8|  -3.816|
# |   17|CA-2014-105893|11/11/2014|11/18/2014|Standard Class|  PK-19075|         Pete Kriz|   Consumer|United States|        Madison|     Wisconsin|     53711|Central|OFF-ST-10004186|            NaN|    Storage|Stur-D-Stor Shelv...|  665.88|       6|     0.0| 13.3176|
# |   18|CA-2014-167164| 5/13/2014| 5/15/2014|  Second Class|  AG-10270|   Alejandro Grove|   Consumer|United States|    West Jordan|          Utah|     84084|   West|OFF-ST-10000107|Office Supplies|    Storage|Fellowes Super St...|    55.5|       2|     0.0|    9.99|
# |   19|CA-2014-143336| 8/27/2014|  9/1/2014|  Second Class|  ZD-21925|Zuschuss Donatelli|   Consumer|United States|  San Francisco|    California|     94109|   West|OFF-AR-10003056|Office Supplies|        Art|          Newell 341|    8.56|       2|     0.0|  2.4824|
# |   20|CA-2014-143336| 8/27/2014|  9/1/2014|  Second Class|  ZD-21925|Zuschuss Donatelli|   Consumer|United States|  San Francisco|    California|     94109|   West|TEC-PH-10001949|     Technology|     Phones|Cisco SPA 501G IP...|  213.48|       3|     0.2|  16.011|
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# only showing top 20 rows

# %% [markdown]
# ## **Handling null values**

# %% [markdown]
# ### **Extract customer name and product category by using existing column values**

# %%
from pyspark.sql import functions

df_1 = superstore_df.groupBy(superstore_df['CustomerID']).agg(functions.first(superstore_df['CustomerName'], ignorenulls=True))
df_2 = superstore_df.groupBy(superstore_df['ProductID']).agg(functions.first(superstore_df['Category'], ignorenulls=True))

df_1.show()
df_2.show()
# Out:
# +----------+--------------------+
# |CustomerID| first(CustomerName)|
# +----------+--------------------+
# |  AA-10315|          Alex Avila|
# |  AA-10375|        Allen Armold|
# |  AA-10480|        Andrew Allen|
# |  AA-10645|       Anna Andreadi|
# |  AB-10015|       Aaron Bergman|
# |  AB-10060|     Adam Bellavance|
# |  AB-10105|       Adrian Barton|
# |  AB-10150|         Aimee Bixby|
# |  AB-10165|         Alan Barnes|
# |  AB-10255|Alejandro Ballentine|
# |  AB-10600|           Ann Blume|
# |  AC-10420|       Alyssa Crouse|
# |  AC-10450|             Amy Cox|
# |  AC-10615|           Ann Chong|
# |  AC-10660|          Anna Chung|
# |  AD-10180|      Alan Dominguez|
# |  AF-10870|        Art Ferguson|
# |  AF-10885|          Art Foster|
# |  AG-10270|     Alejandro Grove|
# |  AG-10300| Aleksandra Gannaway|
# +----------+--------------------+
# only showing top 20 rows
#
# +---------------+---------------+
# |      ProductID|first(Category)|
# +---------------+---------------+
# |FUR-BO-10000112|      Furniture|
# |FUR-BO-10000330|      Furniture|
# |FUR-BO-10000362|      Furniture|
# |FUR-BO-10000468|      Furniture|
# |FUR-BO-10000711|      Furniture|
# |FUR-BO-10000780|      Furniture|
# |FUR-BO-10001337|      Furniture|
# |FUR-BO-10001519|      Furniture|
# |FUR-BO-10001567|      Furniture|
# |FUR-BO-10001601|      Furniture|
# |FUR-BO-10001608|      Furniture|
# |FUR-BO-10001619|      Furniture|
# |FUR-BO-10001798|            NaN|
# |FUR-BO-10001811|      Furniture|
# |FUR-BO-10001918|      Furniture|
# |FUR-BO-10001972|      Furniture|
# |FUR-BO-10002202|      Furniture|
# |FUR-BO-10002206|      Furniture|
# |FUR-BO-10002213|      Furniture|
# |FUR-BO-10002268|      Furniture|
# +---------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### **Join with newly extracted column values**

# %%
df = superstore_df.select('RowID', 'OrderID','OrderDate', 'ShipDate', 'ShipMode', 'CustomerID','Segment','Country', 'City', 'State', 'PostalCode', 'Region', 'ProductID', 'SubCategory', 'ProductName', 'Sales', 'Quantity', 'Discount', 'Profit' )
df = df_1.join(df, 'CustomerID')
df.show()
# Out:
# +----------+-------------------+-----+--------------+----------+----------+--------------+---------+-------------+-------------+------------+----------+-------+---------------+-----------+--------------------+-------+--------+--------+--------+
# |CustomerID|first(CustomerName)|RowID|       OrderID| OrderDate|  ShipDate|      ShipMode|  Segment|      Country|         City|       State|PostalCode| Region|      ProductID|SubCategory|         ProductName|  Sales|Quantity|Discount|  Profit|
# +----------+-------------------+-----+--------------+----------+----------+--------------+---------+-------------+-------------+------------+----------+-------+---------------+-----------+--------------------+-------+--------+--------+--------+
# |  VW-21775|    Victoria Wilson|  213|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|OFF-LA-10004544|     Labels|           Avery 505|  23.68|       2|     0.2|    8.88|
# |  VW-21775|    Victoria Wilson|  214|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|FUR-BO-10004695|  Bookcases|O'Sullivan 2-Door...| 452.45|       5|     0.5|-244.323|
# |  VW-21775|    Victoria Wilson|  215|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|TEC-PH-10002844|     Phones|Speck Products Ca...| 62.982|       3|     0.4|-14.6958|
# |  VW-21775|    Victoria Wilson|  216|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|TEC-MA-10000864|   Machines|Cisco 9971 IP Vid...| 1188.0|       9|     0.7|  -950.4|
# |  VW-21775|    Victoria Wilson|  217|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|TEC-AC-10000109|Accessories|Sony Micro Vault ...| 89.584|       2|     0.2|  4.4792|
# |  VW-21775|    Victoria Wilson| 1520|CA-2017-116204| 2/11/2017| 2/14/2017|  Second Class|Corporate|United States|San Francisco|  California|     94110|   West|OFF-BI-10001759|    Binders|Acco Pressboard C...| 21.336|       7|     0.2|  7.7343|
# |  EM-13960|       Eric Murdock|  162|CA-2015-119697|12/28/2015|12/31/2015|  Second Class| Consumer|United States| Philadelphia|Pennsylvania|     19134|   East|TEC-AC-10003657|Accessories|Lenovo 17-Key USB...| 54.384|       2|     0.2|  1.3596|
# |  MY-17380|    Maribeth Yedwab|  501|US-2016-105578| 5/30/2016|  6/4/2016|Standard Class|Corporate|United States|       Parker|    Colorado|     80134|   West|OFF-BI-10001670|    Binders|Vinyl Sectional P...|  22.62|       2|     0.7|  -15.08|
# +----------+-------------------+-----+--------------+----------+----------+--------------+---------+-------------+-------------+------------+----------+-------+---------------+-----------+--------------------+-------+--------+--------+--------+
# only showing top 20 rows

# %%
df = df_2.join(df, 'ProductID')
df.show()
# Out:
# +---------------+---------------+----------+-------------------+-----+--------------+----------+----------+--------------+---------+-------------+-------------+------------+----------+-------+-----------+--------------------+-------+--------+--------+--------+
# |      ProductID|first(Category)|CustomerID|first(CustomerName)|RowID|       OrderID| OrderDate|  ShipDate|      ShipMode|  Segment|      Country|         City|       State|PostalCode| Region|SubCategory|         ProductName|  Sales|Quantity|Discount|  Profit|
# +---------------+---------------+----------+-------------------+-----+--------------+----------+----------+--------------+---------+-------------+-------------+------------+----------+-------+-----------+--------------------+-------+--------+--------+--------+
# |OFF-LA-10004544|Office Supplies|  VW-21775|    Victoria Wilson|  213|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|     Labels|           Avery 505|  23.68|       2|     0.2|    8.88|
# |FUR-BO-10004695|      Furniture|  VW-21775|    Victoria Wilson|  214|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|  Bookcases|O'Sullivan 2-Door...| 452.45|       5|     0.5|-244.323|
# |TEC-PH-10002844|     Technology|  VW-21775|    Victoria Wilson|  215|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|     Phones|Speck Products Ca...| 62.982|       3|     0.4|-14.6958|
# |TEC-MA-10000864|     Technology|  VW-21775|    Victoria Wilson|  216|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|   Machines|Cisco 9971 IP Vid...| 1188.0|       9|     0.7|  -950.4|
# |TEC-AC-10000109|     Technology|  VW-21775|    Victoria Wilson|  217|CA-2015-146262|  1/2/2015|  1/9/2015|Standard Class|Corporate|United States|       Medina|        Ohio|     44256|   East|Accessories|Sony Micro Vault ...| 89.584|       2|     0.2|  4.4792|
# |OFF-BI-10001759|Office Supplies|  VW-21775|    Victoria Wilson| 1520|CA-2017-116204| 2/11/2017| 2/14/2017|  Second Class|Corporate|United States|San Francisco|  California|     94110|   West|    Binders|Acco Pressboard C...| 21.336|       7|     0.2|  7.7343|
# |TEC-AC-10003657|     Technology|  EM-13960|       Eric Murdock|  162|CA-2015-119697|12/28/2015|12/31/2015|  Second Class| Consumer|United States| Philadelphia|Pennsylvania|     19134|   East|Accessories|Lenovo 17-Key USB...| 54.384|       2|     0.2|  1.3596|
# |OFF-BI-10001670|Office Supplies|  MY-17380|    Maribeth Yedwab|  501|US-2016-105578| 5/30/2016|  6/4/2016|Standard Class|Corporate|United States|       Parker|    Colorado|     80134|   West|    Binders|Vinyl Sectional P...|  22.62|       2|     0.7|  -15.08|
# +---------------+---------------+----------+-------------------+-----+--------------+----------+----------+--------------+---------+-------------+-------------+------------+----------+-------+-----------+--------------------+-------+--------+--------+--------+
# only showing top 20 rows

# %% [markdown]
# ### **Change column names and order them by `RowID`**

# %%
df = df.select('RowID', 'OrderID','OrderDate', 'ShipDate', 'ShipMode', 'CustomerID', 'first(CustomerName)', 'Segment','Country', 'City', 'State', 'PostalCode', 'Region', 'ProductID', 'first(Category)', 'SubCategory', 'ProductName', 'Sales', 'Quantity', 'Discount', 'Profit' ).orderBy('RowID').withColumnRenamed("first(CustomerName)","CustomerName").withColumnRenamed("first(Category)","Category")
df.show()
# Out:
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# |RowID|       OrderID| OrderDate|  ShipDate|      ShipMode|CustomerID|      CustomerName|    Segment|      Country|           City|         State|PostalCode| Region|      ProductID|       Category|SubCategory|         ProductName|   Sales|Quantity|Discount|  Profit|
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# |    1|CA-2016-152156| 11/8/2016|11/11/2016|  Second Class|  CG-12520|       Claire Gute|   Consumer|United States|      Henderson|      Kentucky|     42420|  South|FUR-BO-10001798|            NaN|  Bookcases|Bush Somerset Col...|  261.96|       2|     0.0| 41.9136|
# |    2|CA-2016-152156| 11/8/2016|11/11/2016|  Second Class|  CG-12520|       Claire Gute|   Consumer|United States|      Henderson|      Kentucky|     42420|  South|FUR-CH-10000454|      Furniture|     Chairs|Hon Deluxe Fabric...|  731.94|       3|     0.0| 219.582|
# |    3|CA-2016-138688| 6/12/2016| 6/16/2016|  Second Class|  DV-13045|   Darrin Van Huff|  Corporate|United States|    Los Angeles|    California|     90036|   West|OFF-LA-10000240|Office Supplies|     Labels|Self-Adhesive Add...|   14.62|       2|     0.0|  6.8714|
# |    4|US-2015-108966|10/11/2015|10/18/2015|Standard Class|  SO-20335|    Sean O'Donnell|   Consumer|United States|Fort Lauderdale|       Florida|     33311|  South|FUR-TA-10000577|      Furniture|     Tables|Bretford CR4500 S...|957.5775|       5|    0.45|-383.031|
# |    5|US-2015-108966|10/11/2015|10/18/2015|Standard Class|  SO-20335|    Sean O'Donnell|   Consumer|United States|Fort Lauderdale|       Florida|     33311|  South|OFF-ST-10000760|Office Suplease|    Storage|Eldon Fold 'N Rol...|  22.368|       2|     0.2|  2.5164|
# |    6|CA-2014-115812|  6/9/2014| 6/14/2014|Standard Class|  BH-11710|   Brosina Hoffman|   Consumer|United States|    Los Angeles|    California|     90032|   West
# |   20|CA-2014-143336| 8/27/2014|  9/1/2014|  Second Class|  ZD-21925|Zuschuss Donatelli|   Consumer|United States|  San Francisco|    California|     94109|   West|TEC-PH-10001949|     Technology|     Phones|Cisco SPA 501G IP...|  213.48|       3|     0.2|  16.011|
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# only showing top 20 rows

# %% [markdown]
# ### **Setting defaults value for null values**

# %%
df = df.na.fill({
    "ShipMode": "EMPTY",
    "Segment": "EMPTY",
    "Country": "EMPTY",
    "PostalCode": "EMPTY",
    "Region": "EMPTY",
    "Segment": "EMPTY",
    "SubCategory": "EMPTY",
    "ProductName": "EMPTY",
})

df.show()
# Out:
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# |RowID|       OrderID| OrderDate|  ShipDate|      ShipMode|CustomerID|      CustomerName|    Segment|      Country|           City|         State|PostalCode| Region|      ProductID|       Category|SubCategory|         ProductName|   Sales|Quantity|Discount|  Profit|
# +-----+--------------+----------+----------+--------------+----------+------------------+-----------+-------------+---------------+--------------+----------+-------+---------------+---------------+-----------+--------------------+--------+--------+--------+--------+
# |    1|CA-2016-152156| 11/8/2016|11/11/2016|  Second Class|  CG-12520|       Claire Gute|   Consumer|United States|      Henderson|      Kentucky|     42420|  South|FUR-BO-10001798|            NaN|  Bookcases|Bush Somerset Col...|  261.96|       2|     0.0| 41.9136|
# |    2|CA-2016-152156| 11/8/2016|11/11/2016|  Second Class|  CG-12520|       Claire Gute|   Consumer|United States|      Henderson|      Kentucky|     42420|  South|FUR-CH-10000454|      Furniture|     Chairs|Hon Deluxe Fabric...|  731.94|       3|     0.0| 219.582|
# |    3|CA-2016-138688| 6/12/2016| 6/16/2016|  Second Class|  DV-13045|   Darrin Van Huff|  Corporate|United States|    Los Angeles|    California|     90036|   West|OFF-LA-10000240|Office Supplies|     Labels|Self-Adhesive Add...|   14.62|       2|     0.0|  6.8714|
# |    4|US-2015-108966|10/11/2015|10/18/2015|Standard Class|  SO-20335|    Sean O'Donnell|   Consumer|United States|Fort Lauderdale|       Florida|     33311|  South|FUR-TA-10000577|      Furniture|     Tables|Bretford CR4500 S...|957.5775|       5|    0.45|-383.031|
# |    5|US-2015-108966|10/11/2015|10/18/2015|Standard Class|  SO-20335|    Sean O'Donnell|   Consumer|United States|Fort Lauderdale|       Florida|     33311|  South|OFF-ST-10000760|Office Suplease|    Storage|Eldon Fold 'N Rol...|  22.368|       2|     0.2|  2.5164|
# |    6|CA-2014-115812|  6/9/2014| 6/14/2014|Standard Class|  BH-11710|   Brosina Hoffman|   Consumer|United States|    Los Angeles|    California|     90032|   West|FUR-FU-10001487|      Furniture|Furnishings|Eldon Expressions...|   48.86|       7|     0.0| 14.1694|
# |    7|CA-2014-115812|  6/9/2014| 6/14/2014|Standard Class|  BH-11710|   Brosina Hoffman|   Consumer|United States|    Los Angeles|    California|     90032|   West|OFF-AR-10002833|Office Supplies|        Art|          Newell 322|    7.28|       4|     0.0|  1.9656|
# |    8|CA-2014-115812|  6/9/2014| 6/14/2014|Standard Class|  BH-11710|   Brosina Hoffman|   Consumer|United States|    Los Angeles|    California|     90032|   West|TEC-PH-10002275|     Technology|     Phones|Mitel 5320 IP Pho...| 907.152|       6|     0.2| 90.7152|
# |    9|CA-2014-115812|  6/9/2014| 6/14/2014|Standard Class|  BH-11710|   Brosina Hoffman|   Consumer|United States|    Los Angeles|    California|     90032|   West|OFF-BI-10003910|Office Supplies|    Binders|DXL Angle-View Bi...|  18.504|       3|     0.2|  5.7825|
# |   10|CA-2014-115812|  6/9/2014| 6/14/2014|Standard Class|  BH-11710|   Brosina Hoffman|   Consumer|United States|    Los Angeles|    California|     90032|   West
990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990   9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991   9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992   9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993   9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID      CustomerName    Segment        Country             City  \
# 0      CG-12520       Claire Gute   Consumer  United States        Henderson
# 1      CG-12520       Claire Gute   Consumer  United States        Henderson
# 2      DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...         ...               ...        ...            ...              ...
# 9989   TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993   CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... PostalCode Region        ProductID         Category  SubCategory  \
# 0     ...      42420  South  FUR-BO-10001798              NaN    Bookcases
# 1     ...      42420  South  FUR-CH-10000454        Furniture       Chairs
# 2     ...      90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...      33311  South  FUR-TA-10000577        Furniture       Tables
# 4     ...      33311  South  OFF-ST-10000760  Office Suplease      Storage
# ...   ...        ...    ...              ...              ...          ...
# 9989  ...      33180  South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...      92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...      92627   West  TEC-PH-10003645       Technology       Phones
# 9992  ...      92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...      92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             ProductName       Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.959991         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940002         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620000         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.577515         5
# 4                        Eldon Fold 'N Roll Cart System   22.368000         2
# ...                                                 ...         ...       ...
# 9989                             Ultra Door Pull Handle   25.247999         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.959999         2
# 9991                              Aastra 57i VoIP phone  258.575989         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160004         2
#
#       Discount      Profit
# 0         0.00   41.913601
# 1         0.00  219.582001
# 2         0.00    6.871400
# 3         0.45 -383.031006
# 4         0.20    2.516400
# ...        ...         ...
# 9989      0.20    4.102800
# 9990      0.00   15.633200
# 9991      0.20   19.393200
# 9992      0.00   13.320000
# 9993      0.00   72.947998
#
# [9994 rows x 21 columns]

# %% [markdown]
# ## **Handling spelling mistakes**

# %%
df.Category.value_counts()
# Out:
# Office Supplies    5987
# Furniture          2118
# Technology         1836
# NaN                  30
# Office Suplease      23
# Name: Category, dtype: int64

# %%
df.loc[df.Category == 'Office Suplease' , 'Category'] = 'Office Supplies'

# %%
df.Category.value_counts()
# Out:
# Office Supplies    6010
# Furniture          2118
# Technology         1836
# NaN                  30
# Name: Category, dtype: int64

# %% [markdown]
# ## **Duplicates Handling**

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[df.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [RowID, OrderID, OrderDate, ShipDate, ShipMode, CustomerID, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductID, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.loc[df.duplicated(subset = ['OrderID','CustomerID','ProductID'],keep = False)]
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 26       27  CA-2016-121755   1/16/2016   1/20/2016    Second Class
# 50       51  CA-2016-121755   1/16/2016   1/20/2016    Second Class
# 350     351  CA-2016-129714    9/1/2016    9/3/2016     First Class
# 352     353  CA-2016-129714    9/1/2016    9/3/2016     First Class
# 430     431  US-2016-123750   4/15/2016   4/21/2016  Standard Class
# 431     432  US-2016-123750   4/15/2016   4/21/2016  Standard Class
# 566     567  CA-2017-156951   10/1/2017   10/8/2017  Standard Class
# 695     696  CA-2017-156951   10/1/2017   10/8/2017  Standard Class
# 750     751  CA-2017-126074   10/2/2017   10/6/2017  Standard Class
# 876     877  CA-2017-126074   10/2/2017   10/6/2017  Standard Class
# 1300   1301  CA-2016-137043  12/23/2016  12/25/2016    Second Class
# 1301   1302  CA-2016-137043  12/23/2016  12/25/2016    Second Class
# 3183   3184  CA-2017-152912   11/9/2017  11/12/2017    Second Class
# 750   ...      48183  Central  FUR-FU-10003577        Furniture  Furnishings
# 876   ...      48183  Central  FUR-FU-10003577        Furniture  Furnishings
# 1300  ...      22153    South  FUR-FU-10003664        Furniture  Furnishings
# 1301  ...      22153    South  FUR-FU-10003664        Furniture  Furnishings
# 3183  ...      21044     East  OFF-ST-10003208  Office Supplies      Storage
# 3184  ...      21044     East  OFF-ST-10003208  Office Supplies      Storage
# 3405  ...      43229     East  FUR-CH-10002965        Furniture       Chairs
# 3406  ...      43229     East  FUR-CH-10002965        Furniture       Chairs
# 5219  ...      48205  Central  FUR-CH-10004875        Furniture       Chairs
# 5220  ...      48205  Central  FUR-CH-10004875        Furniture       Chairs
# 6498  ...      40214    South  OFF-BI-10000069  Office Supplies      Binders
# 6500  ...      40214    South  OFF-BI-10000069  Office Supplies      Binders
# 7881  ...      80229     West  TEC-AC-10002006       Technology  Accessories
# 7882  ...      80229     West  TEC-AC-10002006       Technology  Accessories
# 9168  ...      39212    South  OFF-PA-10001954  Office Supplies        Paper
# 9169  ...      39212    South  OFF-PA-10001954  Office Supplies        Paper
#
#                                             ProductName        Sales  \
# 26     Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.570000
# 50     Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.570000
# 350                                          Xerox 1881    24.559999
# 352                                          Xerox 1881    49.119999
# 430   Imation Secure+ Hardware Encrypted USB 2.0 Fla...   408.743988
# 431   Imation Secure+ Hardware Encrypted USB 2.0 Fla...   291.959991
# 566         Personal Creations Ink Jet Cards and Labels    91.839996
# 695         Personal Creations Ink Jet Cards and Labels    91.839996
# 750                          Nu-Dell Leatherette Frames   157.740005
# 876                          Nu-Dell Leatherette Frames   157.740005
# 1300  Electrix Architect's Clamp-On Swing Arm Lamp, ...   572.760010
# 1301  Electrix Architect's Clamp-On Swing Arm Lamp, ...   286.380005
# 3183                 Adjustable Depth Letter/Legal Cart  1633.140015
# 3184                 Adjustable Depth Letter/Legal Cart   544.380005
# 3405  Global Leather Highback Executive Chair with P...   281.372009
# 3406  Global Leather Highback Executive Chair with P...   281.372009
# 5219     Harbour Creations 67200 Series Stacking Chairs   498.260010
# 5220     Harbour Creations 67200 Series Stacking Chairs   498.260010
# 6498  GBC Prepunched Paper, 19-Hole, for Binding Sys...   135.089996
# 6500  GBC Prepunched Paper, 19-Hole, for Binding Sys...    90.059998
# 7881                   Memorex Micro Travel Drive 16 GB    76.751999
# 7882                   Memorex Micro Travel Drive 16 GB   102.335999
# 9168                                         Xerox 1964   319.760010
# 9169                                         Xerox 1964    45.680000
#
#       Quantity  Discount      Profit
# 26           3       0.0   11.774100
# 50           6       0.0   11.774100
# 350          2       0.0   11.543200
# 352          4       0.0   23.086399
# 430          7       0.2   76.639503
# 431          5       0.2   54.742500
# 566          8       0.0   45.001598
# 695          4       0.0   45.001598
# 750         11       0.0   56.786400
# 876          1       0.0   56.786400
# 1300         6       0.0  166.100403
# 1301         3       0.0   83.050201
# 3183         9       0.0  473.610596
# 3184         3       0.0  157.870193
# 3405         2       0.3  -12.058800
# 3406         2       0.3  -12.058800
# 5219         7       0.0  134.530197
# 5220         3       0.0  134.530197
# 6498         9       0.0   62.141399
# 6500         6       0.0   41.427601
# 7881         6       0.2   10.553400
# 7882         8       0.2   14.071200
# 9168        14       0.0  147.089600
# 9169         2       0.0   21.012800
#
# [24 rows x 21 columns]

# %%
df.drop_duplicates(subset = ['OrderID','CustomerID','ProductID'], keep = 'last', inplace=True)

# %%
df.loc[df.duplicated(subset = ['OrderID','CustomerID','ProductID'],keep = False)]
# Out:
# Empty DataFrame
# Columns: [RowID, OrderID, OrderDate, ShipDate, ShipMode, CustomerID, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductID, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.head()
# Out:
#    RowID         OrderID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 1      2  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 2      3  CA-2016-138688   6/12/2016   6/16/2016    Second Class   DV-13045
# 3      4  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
# 4      5  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# 0      Claire Gute   Consumer  United States        Henderson  ...      42420
# 1      Claire Gute   Consumer  United States        Henderson  ...      42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...      90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
#
#   Region        ProductID         Category SubCategory  \
# 0  South  FUR-BO-10001798              NaN   Bookcases
# 1  South  FUR-CH-10000454        Furniture      Chairs
# 2   West  OFF-LA-10000240  Office Supplies      Labels
# 3  South  FUR-TA-10000577        Furniture      Tables
# 4  South  OFF-ST-10000760  Office Supplies     Storage
#
#                                          ProductName       Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.959991         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940002         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.620000         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.577515         5
# 4                     Eldon Fold 'N Roll Cart System   22.368000         2
#
#    Discount      Profit
# 0      0.00   41.913601
# 1      0.00  219.582001
# 2      0.00    6.871400
# 3      0.45 -383.031006
# 4      0.20    2.516400
#
# [5 rows x 21 columns]

# %% [markdown]
# ## **Handling Fixed Bounds**

# %% [markdown]
# ##Sales are bounded for positive values
#
# ##Therefore checking whether having negative values for sales

# %%
(df.Sales < 0).any()
# Out:
# False

# %% [markdown]
# ##Quantity is bounded for positive values
#
# ##Therefore checking whether having negative values for quantity

# %%
(df.Quantity < 0).any()
# Out:
# False

# %% [markdown]
# ##Profit is usually bounded by positive values
#
# ##Therefore checking whether having negative values for profit

# %%
(df.Profit < 0).any()
# Out:
# True

# %% [markdown]
# ##We can consider negative profits to represent the loss

# %%
df.query('Profit < 0')
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 14       15  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 15       16  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 23       24  US-2017-156909   7/16/2017   7/18/2017    Second Class
# 27       28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# ...     ...             ...         ...         ...             ...
# 9920   9921  CA-2016-149272   3/15/2016   3/19/2016  Standard Class
# 9921   9922  CA-2014-111360  11/24/2014  11/30/2014  Standard Class
# 9931   9932  CA-2015-104948  11/13/2015  11/17/2015  Standard Class
# 9937   9938  CA-2016-164889    6/3/2016    6/6/2016    Second Class
# 9962   9963  CA-2015-168088   3/19/2015   3/22/2015     First Class
#
#      CustomerID      CustomerName      Segment        Country  \
# 3      SO-20335    Sean O'Donnell     Consumer  United States
# 14     HP-14815     Harold Pawlan  Home Office  United States
# 15     HP-14815     Harold Pawlan  Home Office  United States
# 23     SF-20065   Sandra Flanagan     Consumer  United States
# 27     TB-21520   Tracy Blumstein     Consumer  United States
# ...         ...               ...          ...            ...
# 9920   MY-18295   Muhammed Yedwab    Corporate  United States
# 9921   AT-10435       Alyssa Tate  Home Office  United States
# 9931   KH-16510     Keith Herrera     Consumer  United States
# 9937   CP-12340    Christine Phan    Corporate  United States
# 9962   CM-12655  Corinna Mitchell  Home Office  United States
#
#                  City  ... PostalCode   Region        ProductID  \
# 3     Fort Lauderdale  ...      33311    South  FUR-TA-10000577
# 14         Fort Worth  ...      76106  Central  OFF-AP-10002311
# 15         Fort Worth  ...      76106  Central  OFF-BI-10000756
# 23       Philadelphia  ...      19140     East  FUR-CH-10002774
# 27       Philadelphia  ...      19140     East  FUR-BO-10004834
# ...               ...  ...        ...      ...              ...
# 9920            Bryan  ...      77803  Central  OFF-BI-10004233
# 9921            Akron  ...      44312     East  OFF-BI-10003350
# 9931   San Bernardino  ...      92404     West  FUR-BO-10004357
# 9937      Los Angeles  ...      90049     West  FUR-TA-10001676
# 9962          Houston  ...      77041  Central  FUR-BO-10004218
#
#              Category SubCategory  \
# 3           Furniture      Tables
# 14    Office Supplies  Appliances
# 15    Office Supplies     Binders
# 23          Furniture      Chairs
# 27          Furniture   Bookcases
# ...               ...         ...
# 9920  Office Supplies     Binders
# 9921  Office Supplies     Binders
# 9931        Furniture   Bookcases
# 9937        Furniture      Tables
# 9962        Furniture   Bookcases
#
#                                             ProductName        Sales  \
# 3         Bretford CR4500 Series Slim Rectangular Table   957.577515
# 14    Holmes Replacement Filter for HEPA Air Cleaner...    68.809998
# 15     Storex DuraTech Recycled Plastic Frosted Binders     2.544000
# 23                   Global Deluxe Stacking Chair, Gray    71.372002
# 27    Riverside Palais Royal Lawyers Bookcase, Royal...  3083.429932
# ...                                                 ...          ...
# 9920  GBC Pre-Punched Binding Paper, Plastic, White,...    22.386000
# 9921                    Acco Expandable Hanging Binders     5.742000
# 9931     O'Sullivan Living Dimensions 3-Shelf Bookcases   683.331970
# 9937       Hon 61000 Series Interactive Training Tables    71.087997
# 9962  Bush Heritage Pine Collection 5-Shelf Bookcase...   383.465607
#
#       Quantity  Discount       Profit
# 3            5      0.45  -383.031006
# 14           5      0.80  -123.858002
# 15           3      0.80    -3.816000
# 23           2      0.30    -1.019600
# 27           7      0.50 -1665.052246
# ...        ...       ...          ...
# 9920         7      0.80   -35.817600
# 9921         3      0.70    -4.593600
# 9931         4      0.15   -40.195999
# 9937         2      0.20    -1.777200
# 9962         4      0.32   -67.670403
#
# [1870 rows x 21 columns]

# %% [markdown]
# ##Discount is bounded for positive values
#
# ##Therefore checking whether having negative values for Discount

# %%
(df.Discount < 0).any()
# Out:
# True

# %%
len(df.query('Discount < 0'))
# Out:
# 17

# %% [markdown]
# ##There are 17 negative values for discount.
#
# ##It is probably a mistake.

# %%
df.query('Discount < 0')
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
#
# 1972        Chicago  ...      60610  Central  OFF-BI-10001249
# 1995        Houston  ...      77036  Central  OFF-AP-10002534
# 2004        Lubbock  ...      79424  Central  OFF-BI-10004738
# 2106       Mesquite  ...      75150  Central  OFF-BI-10003460
# 2137  Grand Prairie  ...      75051  Central  OFF-BI-10002954
# 2159        Chicago  ...      60610  Central  OFF-BI-10004236
# 2167         Laredo  ...      78041  Central  OFF-BI-10004140
#
#              Category SubCategory  \
# 1173  Office Supplies     Binders
# 1271  Office Supplies  Appliances
# 1284  Office Supplies     Binders
# 1332  Office Supplies     Binders
# 1513  Office Supplies     Binders
# 1770  Office Supplies     Binders
# 1818  Office Supplies  Appliances
# 1820  Office Supplies  Appliances
# 1857  Office Supplies     Binders
# 1943  Office Supplies     Binders
# 1972  Office Supplies     Binders
# 1995  Office Supplies  Appliances
# 2004  Office Supplies     Binders
# 2106  Office Supplies     Binders
# 2137  Office Supplies     Binders
# 2159  Office Supplies     Binders
# 2167  Office Supplies     Binders
#
#                                             ProductName       Sales  Quantity  \
# 1173                             GBC Instant Report Kit    5.176000         4
# 1271  Kensington 4 Outlet MasterPiece Compact Power ...   48.792000         3
# 1284          Avery Reinforcements for Hole-Punch Pages    2.772000         7
# 1332            Wilson Jones Easy Flow II Sheet Lifters    1.080000         3
# 1513                      Acco D-Ring Binder w/DublLock   21.379999         5
# 1770  Wilson Jones Leather-Like Binders with DublLoc...   12.222000         7
# 1818                               Harmony Air Purifier   75.599998         2
# 1820  Honeywell Enviracaire Portable Air Cleaner for...   92.064003         6
# 1857  Wilson Jones Elliptical Ring 3 1/2" Capacity B...   34.240002         4
# 1943            Wilson Jones Easy Flow II Sheet Lifters    3.240000         9
# 1972  Avery Heavy-Duty EZD View Binder with Locking ...    5.104000         4
# 1995  3.6 Cubic Foot Counter Height Office Refrigerator  294.619995         5
# 2004  Flexible Leather- Look Classic Collection Ring...   11.364000         3
# 2106                                  Acco 3-Hole Punch    0.876000         1
# 2137  Newell 3-Hole Punched Plastic Slotted Magazine...    3.656000         4
# 2159   XtraLife ClearVue Slant-D Ring Binder, White, 3"    8.808000         3
# 2167                            Avery Non-Stick Binders    6.286000         7
#
#       Discount      Profit
# 1173      -0.8   -7.764000
# 1271      -0.8 -126.859200
# 1284      -0.8   -4.851000
# 1332      -0.8   -1.728000
# 1513      -0.8  -33.139000
# 1770      -0.8  -20.166300
# 1818      -0.8 -166.320007
# 1820      -0.8 -225.556793
# 1857      -0.8  -53.071999
# 1943      -0.8   -5.184000
# 1972      -0.8   -8.676800
# 1995      -0.8 -766.012024
# 2004      -0.8  -17.046000
# 2106      -0.8   -1.401600
# 2137      -0.8   -5.849600
# 2159      -0.8  -14.973600
# 2167      -0.8  -11.000500
#
# [17 rows x 21 columns]

# %%
neg_Discount = df[df.Discount < 0]
neg_Discount
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
#
# 2159        Chicago  ...      60610  Central  OFF-BI-10004236
# 2167         Laredo  ...      78041  Central  OFF-BI-10004140
#
#              Category SubCategory  \
# 1173  Office Supplies     Binders
# 1271  Office Supplies  Appliances
# 1284  Office Supplies     Binders
# 1332  Office Supplies     Binders
# 1513  Office Supplies     Binders
# 1770  Office Supplies     Binders
# 1818  Office Supplies  Appliances
# 1820  Office Supplies  Appliances
# 1857  Office Supplies     Binders
# 1943  Office Supplies     Binders
# 1972  Office Supplies     Binders
# 1995  Office Supplies  Appliances
# 2004  Office Supplies     Binders
# 2106  Office Supplies     Binders
# 2137  Office Supplies     Binders
# 2159  Office Supplies     Binders
# 2167  Office Supplies     Binders
#
#                                             ProductName       Sales  Quantity  \
# 1173                             GBC Instant Report Kit    5.176000         4
# 1271  Kensington 4 Outlet MasterPiece Compact Power ...   48.792000         3
# 1284          Avery Reinforcements for Hole-Punch Pages    2.772000         7
# 1332            Wilson Jones Easy Flow II Sheet Lifters    1.080000         3
# 1513                      Acco D-Ring Binder w/DublLock   21.379999         5
# 1770  Wilson Jones Leather-Like Binders with DublLoc...   12.222000         7
# 1818                               Harmony Air Purifier   75.599998         2
# 1820  Honeywell Enviracaire Portable Air Cleaner for...   92.064003         6
# 1857  Wilson Jones Elliptical Ring 3 1/2" Capacity B...   34.240002         4
# 1943            Wilson Jones Easy Flow II Sheet Lifters    3.240000         9
# 1972  Avery Heavy-Duty EZD View Binder with Locking ...    5.104000         4
# 1995  3.6 Cubic Foot Counter Height Office Refrigerator  294.619995         5
# 2004  Flexible Leather- Look Classic Collection Ring...   11.364000         3
# 2106                                  Acco 3-Hole Punch    0.876000         1
# 2137  Newell 3-Hole Punched Plastic Slotted Magazine...    3.656000         4
# 2159   XtraLife ClearVue Slant-D Ring Binder, White, 3"    8.808000         3
# 2167                            Avery Non-Stick Binders    6.286000         7
#
#       Discount      Profit
# 1173      -0.8   -7.764000
# 1271      -0.8 -126.859200
# 1284      -0.8   -4.851000
# 1332      -0.8   -1.728000
# 1513      -0.8  -33.139000
# 1770      -0.8  -20.166300
# 1818      -0.8 -166.320007
# 1820      -0.8 -225.556793
# 1857      -0.8  -53.071999
# 1943      -0.8   -5.184000
# 1972      -0.8   -8.676800
# 1995      -0.8 -766.012024
# 2004      -0.8  -17.046000
# 2106      -0.8   -1.401600
# 2137      -0.8   -5.849600
# 2159      -0.8  -14.973600
# 2167      -0.8  -11.000500
#
# [17 rows x 21 columns]

# %%
plt.hist(neg_Discount.Discount, bins=30)
plt.title("Distribution of invalid negative Discounts");

# %%
neg_Discount.Discount.value_counts()
# Out:
# -0.8    17
# Name: Discount, dtype: int64

# %%
toBeRemove = df[(df['Discount'] == -0.8)].index
df.drop(toBeRemove , inplace=True)
toBeRemove
# Out:
# Int64Index([1173, 1271, 1284, 1332, 1513, 1770, 1818, 1820, 1857, 1943, 1972,
#             1995, 2004, 2106, 2137, 2159, 2167],
#            dtype='int64')

# %%
df.query('Discount < 0')
# Out:
# Empty DataFrame
# Columns: [RowID, OrderID, OrderDate, ShipDate, ShipMode, CustomerID, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductID, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ##After considering negative discount values we can conclude that,
#
# ###1. There is only one negative discount value which is -0.8.
#
# ###2. Total count of orders is 9994. Among 9994 orders 17 negative discount values are *negligible*.
#
# ###3. Therefore we can drop those rows from dataset.

# %% [markdown]
# ## **Remove Outliers**

# %%
#Boxplot
def plot_boxplot(df , ft):
  df.boxplot(column = [ft])
  plt.grid(False)
  plt.show()

# %%
plot_boxplot(df, 'Quantity')

# %%
plot_boxplot(df , 'Discount')

# %%
# IQR = Q3-Q1

def outliers(df , ft):
  Q1 = df[ft].quantile(0.25)
  Q3 = df[ft].quantile(0.75)
  IQR = Q3-Q1

  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

  ls = df.index[ (df[ft] < lower_bound) | (df[ft] > upper_bound) ]

  return ls

# %%
outlier_indexes = []
for feature in ['Quantity' , 'Discount']:
  outlier_indexes.extend(outliers(df , feature))

# %%
len(outlier_indexes)
# Out:
# 1007

# %%
def remove(df , ls):
  ls = sorted(set(ls))
  df = df.drop(ls)

  return df

# %%
dataset_new =remove(df , outlier_indexes)

# %%
dataset_new.shape
# Out:
# (8970, 21)

# %%
df.shape
# Out:
# (9965, 21)

# %%
plot_boxplot(dataset_new , 'Quantity')

# %%
plot_boxplot(dataset_new , 'Discount')

# %%
df = dataset_new

# %%
df
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 0         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1         2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2         3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4         5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...     ...             ...         ...         ...             ...
# 9989   9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990   9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991   9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992   9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993   9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID      CustomerName    Segment        Country             City  \
# 0      CG-12520       Claire Gute   Consumer  United States        Henderson
# 1      CG-12520       Claire Gute   Consumer  United States        Henderson
# 2      DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4      SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...         ...               ...        ...            ...              ...
# 9989   TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992   DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993   CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... PostalCode Region        ProductID         Category  SubCategory  \
# 0     ...      42420  South  FUR-BO-10001798              NaN    Bookcases
# 1     ...      42420  South  FUR-CH-10000454        Furniture       Chairs
# 2     ...      90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...      33311  South  FUR-TA-10000577        Furniture       Tables
# 4     ...      33311  South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...        ...    ...              ...              ...          ...
# 9989  ...      33180  South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...      92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...      92627   West  TEC-PH-10003645       Technology       Phones
# 9992  ...      92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...      92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             ProductName       Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.959991         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940002         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620000         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.577515         5
# 4                        Eldon Fold 'N Roll Cart System   22.368000         2
# ...                                                 ...         ...       ...
# 9989                             Ultra Door Pull Handle   25.247999         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.959999         2
# 9991                              Aastra 57i VoIP phone  258.575989         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160004         2
#
#       Discount      Profit
# 0         0.00   41.913601
# 1         0.00  219.582001
# 2         0.00    6.871400
# 3         0.45 -383.031006
# 4         0.20    2.516400
# ...        ...         ...
# 9989      0.20    4.102800
# 9990      0.00   15.633200
# 9991      0.20   19.393200
# 9992      0.00   13.320000
# 9993      0.00   72.947998
#
# [8970 rows x 21 columns]

# %% [markdown]
# #clustering

# %%
#from sklearn.preprocessing import normalize
#numeric_df = df[['Sales','Quantity','Discount','Profit']].copy()
#data_scaled = normalize(numeric_df)
#data_scaled = pd.DataFrame(data_scaled, columns=numeric_df.columns)
#data_scaled

# %%
#import scipy.cluster.hierarchy as shc
#plt.figure(figsize=(10, 7))  
#plt.title("Dendrograms")  
#dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))

# %%
#plt.figure(figsize=(10, 7))  
#plt.title("Dendrograms")  
#dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
#plt.axhline(y=6, color='r', linestyle='--')

# %%
#from sklearn.cluster import AgglomerativeClustering
#cluster = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')  
#f1 = cluster.fit_predict(data_scaled)
#print(f1)

# %%
#plt.figure(figsize=(10, 7))  
#plt.scatter(data_scaled['Sales'], data_scaled['Profit'], c=cluster.labels_)

# %%
#plt.figure(figsize=(10, 7))  
#plt.scatter(data_scaled['Sales'], data_scaled['Discount'], c=cluster.labels_)

# %%
#plt.figure(figsize=(10, 7))  
#plt.scatter(data_scaled['Profit'], data_scaled['Discount'], c=cluster.labels_)

# %%
#plt.figure(figsize=(10, 7))  
#plt.scatter(data_scaled['Quantity'], data_scaled['Discount'], c=cluster.labels_)

# %% [markdown]
# #Classifications

# %%
# Importing Libraries

import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, StratifiedKFold, StratifiedShuffleSplit

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from xgboost import XGBClassifier

from sklearn.metrics import mean_absolute_error, accuracy_score, classification_report, confusion_matrix

# %%
df = df[['OrderID','OrderDate','ShipMode','CustomerID','Segment', 'City', 'State', 'Region', 'ProductID', 'SubCategory', 'ProductName', 'Sales', 'Quantity', 'Discount', 'Profit']].copy()
#df = df[['OrderDate','City','SubCategory','Discount']].copy()
df
# Out:
#              OrderID   OrderDate        ShipMode CustomerID    Segment  \
# 0     CA-2016-152156   11/8/2016    Second Class   CG-12520   Consumer
# 1     CA-2016-152156   11/8/2016    Second Class   CG-12520   Consumer
# 2     CA-2016-138688   6/12/2016    Second Class   DV-13045  Corporate
# 3     US-2015-108966  10/11/2015  Standard Class   SO-20335   Consumer
# 4     US-2015-108966  10/11/2015  Standard Class   SO-20335   Consumer
# ...              ...         ...             ...        ...        ...
# 9989  CA-2014-110422   1/21/2014    Second Class   TB-21400   Consumer
# 9990  CA-2017-121258   2/26/2017  Standard Class   DB-13060   Consumer
# 9991  CA-2017-121258   2/26/2017  Standard Class   DB-13060   Consumer
# 9992  CA-2017-121258   2/26/2017  Standard Class   DB-13060   Consumer
# 9993  CA-2017-119914    5/4/2017    Second Class   CC-12220   Consumer
#
#                  City       State Region        ProductID  SubCategory  \
# 0           Henderson    Kentucky  South  FUR-BO-10001798    Bookcases
# 1           Henderson    Kentucky  South  FUR-CH-10000454       Chairs
# 2         Los Angeles  California   West  OFF-LA-10000240       Labels
# 3     Fort Lauderdale     Florida  South  FUR-TA-10000577       Tables
# 4     Fort Lauderdale     Florida  South  OFF-ST-10000760      Storage
# ...               ...         ...    ...              ...          ...
# 9989            Miami     Florida  South  FUR-FU-10001889  Furnishings
# 9990       Costa Mesa  California   West  FUR-FU-10000747  Furnishings
# 9991       Costa Mesa  California   West  TEC-PH-10003645       Phones
# 9992       Costa Mesa  California   West  OFF-PA-10004041        Paper
# 9993      Westminster  California   West  OFF-AP-10002684   Appliances
#
#                                             ProductName       Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.959991         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940002         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620000         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.577515         5
# 4                        Eldon Fold 'N Roll Cart System   22.368000         2
# ...                                                 ...         ...       ...
# 9989                             Ultra Door Pull Handle   25.247999         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.959999         2
# 9991                              Aastra 57i VoIP phone  258.575989         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160004         2
#
#       Discount      Profit
# 0         0.00   41.913601
# 1         0.00  219.582001
# 2         0.00    6.871400
# 3         0.45 -383.031006
# 4         0.20    2.516400
# ...        ...         ...
# 9989      0.20    4.102800
# 9990      0.00   15.633200
# 9991      0.20   19.393200
# 9992      0.00   13.320000
# 9993      0.00   72.947998
#
# [8970 rows x 15 columns]

# %%
df.loc[df['Discount'] > 0, 'Discount'] = 'Y'
df.loc[df['Discount'] == 0, 'Discount'] = 'N'
df
# Out:
#              OrderID   OrderDate        ShipMode CustomerID    Segment  \
# 0     CA-2016-152156   11/8/2016    Second Class   CG-12520   Consumer
# 1     CA-2016-152156   11/8/2016    Second Class   CG-12520   Consumer
# 2     CA-2016-138688   6/12/2016    Second Class   DV-13045  Corporate
# 3     US-2015-108966  10/11/2015  Standard Class   SO-20335   Consumer
# 4     US-2015-108966  10/11/2015  Standard Class   SO-20335   Consumer
# ...              ...         ...             ...        ...        ...
# 9989  CA-2014-110422   1/21/2014    Second Class   TB-21400   Consumer
# 9990  CA-2017-121258   2/26/2017  Standard Class   DB-13060   Consumer
# 9991  CA-2017-121258   2/26/2017  Standard Class   DB-13060   Consumer
# 9992  CA-2017-121258   2/26/2017  Standard Class   DB-13060   Consumer
# 9993  CA-2017-119914    5/4/2017    Second Class   CC-12220   Consumer
#
#                  City       State Region        ProductID  SubCategory  \
# 0           Henderson    Kentucky  South  FUR-BO-10001798    Bookcases
# 1           Henderson    Kentucky  South  FUR-CH-10000454       Chairs
# 2         Los Angeles  California   West  OFF-LA-10000240       Labels
# 3     Fort Lauderdale     Florida  South  FUR-TA-10000577       Tables
# 4     Fort Lauderdale     Florida  South  OFF-ST-10000760      Storage
# ...               ...         ...    ...              ...          ...
# 9989            Miami     Florida  South  FUR-FU-10001889  Furnishings
# 9990       Costa Mesa  California   West  FUR-FU-10000747  Furnishings
# 9991       Costa Mesa  California   West  TEC-PH-10003645       Phones
# 9992       Costa Mesa  California   West  OFF-PA-10004041        Paper
# 9993      Westminster  California   West  OFF-AP-10002684   Appliances
#
#                                             ProductName       Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.959991         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940002         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620000         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.577515         5
# 4                        Eldon Fold 'N Roll Cart System   22.368000         2
# ...                                                 ...         ...       ...
# 9989                             Ultra Door Pull Handle   25.247999         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.959999         2
# 9991                              Aastra 57i VoIP phone  258.575989         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160004         2
#
#      Discount      Profit
# 0           N   41.913601
# 1           N  219.582001
# 2           N    6.871400
# 3           Y -383.031006
# 4           Y    2.516400
# ...       ...         ...
# 9989        Y    4.102800
# 9990        N   15.633200
# 9991        Y   19.393200
# 9992        N   13.320000
# 9993        N   72.947998
#
# [8970 rows x 15 columns]

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# %%
df['OrderDate'] = df['OrderDate'].dt.isocalendar().week
df.columns = ['OrderID','OrderWeek','ShipMode','CustomerID','Segment', 'City', 'State', 'Region', 'ProductID', 'SubCategory', 'ProductName', 'Sales', 'Quantity', 'Discount', 'Profit']
df
#'RowID', 'OrderID','OrderDate', 'ShipDate', 'ShipMode', 'CustomerID','Segment','Country', 'City', 'State', 'PostalCode', 'Region', 'ProductID', 'SubCategory', 'ProductName', 'Sales', 'Quantity', 'Discount', 'Profit' )
# Out:
#              OrderID  OrderWeek        ShipMode CustomerID    Segment  \
# 0     CA-2016-152156         45    Second Class   CG-12520   Consumer
# 1     CA-2016-152156         45    Second Class   CG-12520   Consumer
# 2     CA-2016-138688         23    Second Class   DV-13045  Corporate
# 3     US-2015-108966         41  Standard Class   SO-20335   Consumer
# 4     US-2015-108966         41  Standard Class   SO-20335   Consumer
# ...              ...        ...             ...        ...        ...
# 9989  CA-2014-110422          4    Second Class   TB-21400   Consumer
# 9990  CA-2017-121258          8  Standard Class   DB-13060   Consumer
# 9991  CA-2017-121258          8  Standard Class   DB-13060   Consumer
# 9992  CA-2017-121258          8  Standard Class   DB-13060   Consumer
# 9993  CA-2017-119914         18    Second Class   CC-12220   Consumer
#
#                  City       State Region        ProductID  SubCategory  \
# 0           Henderson    Kentucky  South  FUR-BO-10001798    Bookcases
# 1           Henderson    Kentucky  South  FUR-CH-10000454       Chairs
# 2         Los Angeles  California   West  OFF-LA-10000240       Labels
# 3     Fort Lauderdale     Florida  South  FUR-TA-10000577       Tables
# 4     Fort Lauderdale     Florida  South  OFF-ST-10000760      Storage
# ...               ...         ...    ...              ...          ...
# 9989            Miami     Florida  South  FUR-FU-10001889  Furnishings
# 9990       Costa Mesa  California   West  FUR-FU-10000747  Furnishings
# 9991       Costa Mesa  California   West  TEC-PH-10003645       Phones
# 9992       Costa Mesa  California   West  OFF-PA-10004041        Paper
# 9993      Westminster  California   West  OFF-AP-10002684   Appliances
#
#                                             ProductName       Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.959991         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940002         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620000         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.577515         5
# 4                        Eldon Fold 'N Roll Cart System   22.368000         2
# ...                                                 ...         ...       ...
# 9989                             Ultra Door Pull Handle   25.247999         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.959999         2
# 9991                              Aastra 57i VoIP phone  258.575989         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160004         2
#
#      Discount      Profit
# 0           N   41.913601
# 1           N  219.582001
# 2           N    6.871400
# 3           Y -383.031006
# 4           Y    2.516400
# ...       ...         ...
# 9989        Y    4.102800
# 9990        N   15.633200
# 9991        Y   19.393200
# 9992        N   13.320000
# 9993        N   72.947998
#
# [8970 rows x 15 columns]

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="Discount", data=df, palette=sns.xkcd_palette(["azure", "light red"]))
plt.xlabel('Discount')
plt.ylabel('Count')
# plt.savefig('./plots/status_count.png')
plt.show()

# %%
le = LabelEncoder()
df['OrderID'] = le.fit_transform(df['OrderID'])
df['City'] = le.fit_transform(df['City'])
df['OrderWeek'] = le.fit_transform(df['OrderWeek'])
df['ShipMode'] = le.fit_transform(df['ShipMode'])
df['Segment'] = le.fit_transform(df['Segment'])
df['ProductName'] = le.fit_transform(df['ProductName'])
df['CustomerID'] = le.fit_transform(df['CustomerID'])
df['State'] = le.fit_transform(df['State'])
df['Region'] = le.fit_transform(df['Region'])
df['Sales'] = le.fit_transform(df['Sales'])
df['SubCategory'] = le.fit_transform(df['SubCategory'])
df['Quantity'] = le.fit_transform(df['Quantity'])
df['Discount'] = le.fit_transform(df['Discount'])
df['Profit'] = le.fit_transform(df['Profit'])
df['ProductID'] = le.fit_transform(df['ProductID'])

# %%
# Correlation Heatmap

fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = True, ax=ax)
# plt.savefig('./plots/correlation_heatmap.png')
plt.show()

# %%
df['City'].values
# Out:
# array([189, 189, 260, ..., 102, 102, 505])

# %%
print(df["City"].unique())
# Out:
# [189 260 149  94 442 266 501 428 154 365 344 202 397 314 282 126 504 121
#  317 322 477  78 162 454 210 283 114 125  91 401 294 417  23  72 345 483
#   92 509  40 366 408 205 356 323 152 441 430 131  64 424 301 143 168 390
#  182 503   1 117 507 413 107 281 123 120 463 438 234 427  48  71 307  81
#  207 380 462  90  34 464 235  15  17 179 419 256 191 310 244  24 263 268
#  184 478 384 361 118 240 492 289 203 398 261 242  63 321 160 211  22 329
#    7 252 204 146 102 354  20 163 171 233 303 287 173 150   8 277 420 238
#  112 491 485 297 402 369 445 486  84 482  59 499  76  67 352 309 192 336
#  141 476 103  44 236  18 231 341 132 436 293 147 259 251 421 319 159 333
#    3 474 145 400 475 410  41 488 312 340 493 213 418  53 515 335  86 137
#  409 215  11 199 226 237 106 394 185 139 411 405 100  55  46 178 155 265
#   69 381 116 311 290 153 367 382 372 448 355 299 318 209 487 164 325 470
#  505  98 374 331   5 466 229  49 142 496  14  35   4 134 170 362  66 220
#  228 473 447 370 457 206  30  27 219 339 479 391 385 313 285  45 449  50
#  452 217 377 280  73 298 388  52 359 338  75 214 425 248  47 363 342 386
#  304 456 459 516  89 416 271 423 422 223 253 250 275  28 450 320 291 446
#  148  83 412 472 267 198   2  88 136 358 330 324 212 296 227 461 316  36
#  513 181 506 458 201 138 239 200 156 497  26 375 101 392 346 343 230 194
#  188 326  13 308 455 129 364  39 177  74 286  43 272 512 360 433 169 489
#  348 465 517 396  95 124 113 439 193  65 415 288 332 371 403 337 500  80
#  269   6 174 471 467 130  31 176 514 378 460  33 104  51 295 197 508 279
#  208  42 105 376  82 469 111  57 379 144 135 429 273 434 284 243 183 407
#  224 249 186 109 255 494  19  12  25 274 498 357 334 245 157 247 480 305
#  161 262  70 187 221 383 490  37 175 167 511 353 406  87 216 451 404 437
#   68 327 122  10 225 373 196 292  56 232 389  79 484  96  77 349  60 218
#  315  29 393 246 440 119 258 190 495  62 351  38 140 350 395 165 115  93
#  468 510 399 166 302 133 151  32 502 328 414  61 518 195  58 300 158  21
#  257 110 306  85 443 128 387   9 222 444 108 264 435 432 172 270 481  99
#  276 241  54 368   0 180 127  16 347  97 426 431 453 254 278]

# %%
print(df["SubCategory"].unique())
# Out:
# [ 4  5 10 16 14  9  2 13  3  1 12  7  0  8 15 11  6]

# %%
print(df["Discount"].unique())
# Out:
# [0 1]

# %%
print(df["SubCategory"].unique())
# Out:
# [ 4  5 10 16 14  9  2 13  3  1 12  7  0  8 15 11  6]

# %%
# X = features & y = Target class

X = df.drop(['Discount'], axis=1)
y = df['Discount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
cv = StratifiedShuffleSplit(n_splits=10, test_size=.30, random_state=15)

# %%
# Building our model with K-fold validation and GridSearch to find the best parameters

# No such parameters for Gaussian Naive Bayes
params = {}

# Building model
gb = GaussianNB()

# Parameter estimating using GridSearch
grid = GridSearchCV(gb, param_grid=params, scoring='accuracy', n_jobs =-1, cv=cv, verbose=1)

# Fitting the model
grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=15, test_size=0.3,
#             train_size=None),
#              estimator=GaussianNB(), n_jobs=-1, param_grid={},
#              scoring='accuracy', verbose=1)

# %%
gb_grid_val_score = grid.best_score_
print('Best Score:', gb_grid_val_score)
print('Best Estimator:', grid.best_estimator_)
# Out:
# Best Score: 0.678184713375796
# Best Estimator: GaussianNB()

# %%
# Using the best parameters from the grid-search and predicting on test feature dataset(X_test)

gb_grid= grid.best_estimator_
y_pred = gb_grid.predict(X_test)

# %%
# Confusion matrix

pd.DataFrame(confusion_matrix(y_test,y_pred), columns=["Predicted YES", "Predicted NO"], index=["Actual YES","Actual NO"] )
# Out:
#             Predicted YES  Predicted NO
# Actual YES           1078           322
# Actual NO             541           750

# %%
# Calculating metrics

gb_grid_score = accuracy_score(y_test, y_pred)
print('Model Accuracy:', gb_grid_score)
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.6793013749535489
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.77      0.71      1400
#            1       0.70      0.58      0.63      1291
#
#     accuracy                           0.68      2691
#    macro avg       0.68      0.68      0.67      2691
# weighted avg       0.68      0.68      0.68      2691

# %%
#importing random forest classifier from assemble module
from sklearn.ensemble import RandomForestClassifier
#creating a RF classifier
classifier = RandomForestClassifier(n_estimators = 100)

#Training the model on the training dataset
#fit function is used to train the model using the training sets as parameters
classifier.fit(X_train, y_train)
#performing predictions on the test dataset
y_pred = classifier.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
#metrics are used to find accuracy or error
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2)
# Out:
# Confusion Matrix:
# [[1380   20]
#  [  29 1262]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1400
#            1       0.98      0.98      0.98      1291
#
#     accuracy                           0.98      2691
#    macro avg       0.98      0.98      0.98      2691
# weighted avg       0.98      0.98      0.98      2691
#
# Accuracy: 0.9817911557041992
